# %%
import pandas as pd
df_and1 = pd.read_csv("/content/prompts.csv")
df_and2 = pd.read_csv("/content/andrey_prompts.csv")

# %%
df_and1
# Out:
#     Analyze the sociopolitical factors that influenced the fall of the Roman Empire and discuss its lasting impacts on European culture.  \
# 0    Explain the biochemical mechanisms through whi...
# 1    Analyze the portrayal of the human condition a...
# 2    How is the use of machine learning and predict...
# 3    Evaluate the potential ecological and socio-ec...
# 4    Discuss the transformation of mass media in th...
# ..                                                 ...
# 120  Explain the theory of relativity and its impli...
# 121  Analyze the theme of power in George Orwell's ...
# 122  How is artificial intelligence being used in h...
# 123  Evaluate the potential implications of overfis...
# 124                                                NaN
#
#     Roman Empire, how did it fall and what changed after?  Unnamed: 2  \
# 0     Sugar in the body and diabetes, what's the deal?            NaN
# 1    "Waiting for Godot" and life's big questions, ...            NaN
# ...

# %%
df_and2
# Out:
#      Describe a moment when you experienced profound joy.  \
# 0     Imagine you are a detective in a noir film. De...
# 1     Discuss the economic implications of climate c...
# 2     Tell a story about a child who befriends a myt...
# 3     Outline a strategy for boosting renewable ener...
# 4     Discuss the cultural significance of Van Gogh'...
# ...                                                 ...
# 1007  Analyze the portrayal of ambition and power in...
# 1008  Write a descriptive account of a bustling nigh...
# 1009  Discuss the potential impacts of global warmin...
# 1010  Write a ghost story set in an eerie lighthouse...
# 1011  Explain the concept of the food chain to a sec...
#
#           Talk about a time when you were really happy.  Unnamed: 2  \
# 0             You're a detective. What's the city like?         NaN
# 1     What's climate change got to do with a city by...         NaN
# 2            Write about a kid and a mythical creature.         NaN
# ...

# %%
df_new1 = pd.DataFrame()

# %%
df_new1["bad_prompts"] = df_and1["Roman Empire, how did it fall and what changed after?"]
df_new1["improved_prompts"] = df_and1["Analyze the sociopolitical factors that influenced the fall of the Roman Empire and discuss its lasting impacts on European culture."]
df_new1
# Out:
#                                            bad_prompts  \
# 0     Sugar in the body and diabetes, what's the deal?
# 1    "Waiting for Godot" and life's big questions, ...
# 2    Machine learning, big data and business, how d...
# 3    Palm oil production in Southeast Asia, any pro...
# 4      Internet, media and journalism, what's changed?
# ..                                                 ...
# 120            Relativity theory, can you simplify it?
# 121            "1984," what's it got to do with power?
# 122                AI and healthcare, how do they mix?
# 123              Overfishing, is it bad for the ocean?
# 124                                                NaN
#
#                                       improved_prompts
# 0    Explain the biochemical mechanisms through whi...
# 1    Analyze the portrayal of the human condition a...
# 2    How is the use of machine learning and predict...
# 3    Evaluate the potential ecological and socio-ec...
# ...

# %% [markdown]
# ## Same for the other file

# %%
df_new2 = pd.DataFrame()
df_new2["bad_prompts"] = df_and2["Talk about a time when you were really happy."]
df_new2["improved_prompts"] = df_and2["Describe a moment when you experienced profound joy."]
df_new2
# Out:
#                                             bad_prompts  \
# 0             You're a detective. What's the city like?
# 1     What's climate change got to do with a city by...
# 2            Write about a kid and a mythical creature.
# 3     How can we use more renewable energy in the ne...
# 4               What's so special about "Starry Night?"
# ...                                                 ...
# 1007  What does "Macbeth" say about ambition and power?
# 1008             Write about a night market in Bangkok.
# 1009         What can global warming do to agriculture?
# 1010               Write a ghost story in a lighthouse.
# 1011                             What's the food chain?
#
#                                        improved_prompts
# 0     Imagine you are a detective in a noir film. De...
# 1     Discuss the economic implications of climate c...
# 2     Tell a story about a child who befriends a myt...
# 3     Outline a strategy for boosting renewable ener...
# ...

# %% [markdown]
# ## Merge

# %%
df_andrey = pd.concat([df_new1, df_new2])

# %%
df_andrey
# Out:
#                                             bad_prompts  \
# 0      Sugar in the body and diabetes, what's the deal?
# 1     "Waiting for Godot" and life's big questions, ...
# 2     Machine learning, big data and business, how d...
# 3     Palm oil production in Southeast Asia, any pro...
# 4       Internet, media and journalism, what's changed?
# ...                                                 ...
# 1007  What does "Macbeth" say about ambition and power?
# 1008             Write about a night market in Bangkok.
# 1009         What can global warming do to agriculture?
# 1010               Write a ghost story in a lighthouse.
# 1011                             What's the food chain?
#
#                                        improved_prompts
# 0     Explain the biochemical mechanisms through whi...
# 1     Analyze the portrayal of the human condition a...
# 2     How is the use of machine learning and predict...
# 3     Evaluate the potential ecological and socio-ec...
# ...

# %% [markdown]
# ## Merging andrey's work with Jay, and Daniel's

# %%
df_jd = pd.read_csv("Jay_Daniel_prompts.csv", encoding_errors = 'ignore')
df_jd.rename(columns={df_jd.columns[0]: 'bad_prompts'}, inplace = True)
df_jd.rename(columns={df_jd.columns[1]: 'improved_prompts'},inplace=True)
df_jd
# Out:
#                                           bad_prompts  \
# 0   Write a program that calculates the area of a ...
# 1   Build an app that tracks daily fitness activities
# 2     Make a program that simulates a blackjack game.
# 3   Write code to analyze a large dataset and extr...
# 4   Create a chatbot using natural language proces...
# ..                                                ...
# 75     Show me how to calculate the average of a list
# 76       Show me how to code to reverse a string in C
# 77  I want to know how to find the smallest elemen...
# 78  Code for calculating the sum of even numbers i...
# 79  JavaScript code for converting a string to low...
#
#                                      improved_prompts
# 0    "Implement a Python program that takes the le...
# 1    "Design and develop a mobile app for iOS and ...
# 2    "Create a Java program that simulates a black...
# 3    "Develop a data analysis script in Python tha...
# ...

# %%
df_merged = pd.concat([df_jd, df_andrey])

# %%
df_merged
# Out:
#                                             bad_prompts  \
# 0     Write a program that calculates the area of a ...
# 1     Build an app that tracks daily fitness activities
# 2       Make a program that simulates a blackjack game.
# 3     Write code to analyze a large dataset and extr...
# 4     Create a chatbot using natural language proces...
# ...                                                 ...
# 1007  What does "Macbeth" say about ambition and power?
# 1008             Write about a night market in Bangkok.
# 1009         What can global warming do to agriculture?
# 1010               Write a ghost story in a lighthouse.
# 1011                             What's the food chain?
#
#                                        improved_prompts
# 0      "Implement a Python program that takes the le...
# 1      "Design and develop a mobile app for iOS and ...
# 2      "Create a Java program that simulates a black...
# 3      "Develop a data analysis script in Python tha...
# ...

# %% [markdown]
# ## To_csv

# %%
df_merged.to_csv("bad-improved-prompt-pairs.csv", index = False)

# %%
df = pd.read_csv("/content/bad-improved-prompt-pairs.csv")
df
# Out:
#                                             bad_prompts  \
# 0     Write a program that calculates the area of a ...
# 1     Build an app that tracks daily fitness activities
# 2       Make a program that simulates a blackjack game.
# 3     Write code to analyze a large dataset and extr...
# 4     Create a chatbot using natural language proces...
# ...                                                 ...
# 1212  What does "Macbeth" say about ambition and power?
# 1213             Write about a night market in Bangkok.
# 1214         What can global warming do to agriculture?
# 1215               Write a ghost story in a lighthouse.
# 1216                             What's the food chain?
#
#                                        improved_prompts
# 0      "Implement a Python program that takes the le...
# 1      "Design and develop a mobile app for iOS and ...
# 2      "Create a Java program that simulates a black...
# 3      "Develop a data analysis script in Python tha...
# ...
